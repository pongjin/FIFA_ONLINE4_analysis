# %%
포지션 설정
1.중앙공격 : rs ls st cf rf lf : 20 21 22 24 25 26
2.측면공격 : lw rw : 23 27 / rm lm: 12 16 / ram lam : 17 19 
3.중앙 cam, rcm cm lcm: 13 14 15 18 / cdm rdm ldm: 9, 10, 11
4.측면수비rb lb rwb lwb: 2,3,7,8
5.중앙수비 : cb sw: 1,5 / rcb lcb: 4,6
sub : 28

최종 변수선정
1. possession	Integer	점유율
2. OffsideCount	Integer	오프사이드 수
3. shootTotal	Integer	총 슛 수(세트피스, PK 제외)
4. shootHeading	Integer	헤딩 슛 수(세트피스 제외)
5. shootInPenalty	Integer	인패널티 슛 수(세트피스, PK 제외)
6. shootOutPenalty	Integer	아웃패널티 슛 수(세트피스, PK 제외)
7.  passTry	Integer	총 패스 시도 수
8. shortPassTry	Integer	숏 패스 시도 수
9. longPassTry+bouncingLobPassTry	Integer	롱 패스 시도 수
10. throughPassTry + lobbedThroughPassTry 스루 패스 시도 수w QW
11. blockTry+ tackleTry	Integer	총 수비 시도 수
15. dribble  (4)윙백의 공격 가담 여부
------------------------------------------------------------
12. shoot	Integer	슛 수 (1,2,3)
21. pass	Integer / total	패스 비율(1,2,3,4,5)
16. dribble	Integer	드리블 거리(야드) (1,2,3)
19. intercept + defending + block + tackle  공격의 수비가담(1,2)


26개 변수

# %% [markdown]
# # 게임 open API
# ## 링크
# 대부분 json 형식으로 제공함
# 1. 넥슨 ( 카트라이더, 피파 정도가 분석 가능할듯..? ) [링크](https://developers.nexon.com/)
#
# 아래 사이트들은 영어
# 2. 블리자드 ( 스타, 옵치 등 ) [링크](https://develop.battle.net/)
# 3. 라이엇 ( 롤, TFT, 발로란트 ) [링크](https://developer.riotgames.com/)
# 4. 스팀 ( 게임 장르 및 리뷰 등) [링크](https://partner.steamgames.com/doc/webapi_overview)
# 5. Rapid API : 다양한 게임의 api를 모아놓은 사이트 [링크](https://rapidapi.com/category/Gaming)
#
# 이 외 다양한 사이트들이 있지만, 죄다 영어임..
# ***
# ## 분석 사례
# 구글에 해당 api들을 검색해보면 블로그에서 많이 다룸
#
# 1. 스팀게임 추천시스템 [링크](https://weejw.tistory.com/555)
# 2. 피파4 분석 사례 [링크](https://hojjimin-statistic.tistory.com/m/2)
# 3. 카트라이더 [링크](https://velog.io/@colacan100/KartriderMetaAnalysisProject-Result)
# 4.

# %% [markdown]
# # API 사용법 예시
# 카트라이더 : [링크](https://jvvp.tistory.com/1095)
#
# **롤이나 스타같은 게임데이터는 도메인 지식이 필요할것 같음.
# 쉽게 접근할 수 있는 모바일 게임 api를 찾아봤지만 소득은 없었음!**
# <br>
#
# <br>
#
# 좀 더 접근성이 쉬운 게임의 API를 찾으면 좋을것 같음 !

# %% [markdown]
# # API를 불러와 DataFrame으로 만드는 간단한 예시
# 코드는 대충 짠거라서 찾아보면 훨씬 깔끔한 코드가 많을것 같음!
# ***
# ###피파 데이터를 활용하여 최근 10경기 전적을 보고자한다. (데이터 출처 : 이**사원님)
#
# 1. 유저 id
# 2. 경기일자
# 1. 승패
# 2. 골득실
#
# 아래 링크는 포메이션과 전술에 대해 잘 설명해놓은 블로그이다.
# https://thegoat.tistory.com/62
#
# # 게임
# 승패
# 파울
# 카드
# 드리블거리
# 코너킥
# 점유율
# 오프사이드
# 경기평점
# 포메이션(공미수 선수 숫자비율이나 포지션으로 대략적인 그림 만들어보기)
# 포메이션 스코어
# 1 - 공격수(CF)
# 0.75 - 공미(AM), 윙포워드(WF)
# 0.5 - 중미(CM), 측면미드필더(WM)
# 0.25 - 수미(DM), 윙백(WB) / 3.75
# >1(공격) <1(수비)
#
# 위는 포메이션 스코어로 플레이 포지션점수를 합산한 다음 3.75로 나누면
# --------------------
# # 슈팅
# 슈팅횟수(승부차기는 제외)
# 골득실
# 헤딩
# 패널티 내외
# --------------------
# # 패스
# 패스횟수(숏, 롱 따로)
# 스루패스
# 로빙스루패스
# ---------------------
# # 수비
# 블락수
# 태클수

# %%
# packages
import json
import requests # 웹으로 요청하기 위해 필요함

import pandas as pd
import numpy as np

# %%
# api key 할당
api_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiNTAwOjEwIiwiYWNjb3VudF9pZCI6IjQxOTY1MzAwNCIsImF1dGhfaWQiOiIyIiwiZXhwIjoxNjk2MTY3NjEzLCJpYXQiOjE2ODA2MTU2MTMsIm5iZiI6MTY4MDYxNTYxMywic2VydmljZV9pZCI6IjQzMDAxMTQ4MSIsInRva2VuX3R5cGUiOiJBY2Nlc3NUb2tlbiJ9.o0LLbN5McbgsFrXA8aq8_iczl1hrATz-4QhGTPLBeCQ'

# %%
# 유저 닉네임을 통해 accessid 발급
user_params = { 'nickname' : '가가나나다라'}
headers = {'Authorization' : api_key}
user_info = requests.get('https://api.nexon.co.kr/fifaonline4/v1.0/users?', params = user_params, headers = headers)
user_data = user_info.json()

print(user_data) # id, 별명, 레벨 조회

accessid = user_data['accessId'] # accessId 할당
# Out:
# {'accessId': 'ec99bd306d297d1c382a7c03', 'nickname': '가가나나다라', 'level': 475}

# %%
# 매치 종류 조회
match_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/matchtype.json')
match_url_data = match_url.json()
pd.DataFrame(match_url_data) # 공식 경기 : 50
# Out:
#    matchtype      desc
# 0         30     리그 친선
# 1         40  클래식 1on1
# 2         50      공식경기
# 3         52      감독모드
# 4         60     공식 친선
# 5        204     볼타 친선
# 6        214     볼타 공식
# 7        224   볼타 AI대전
# 8        234    볼타 커스텀

# %%
 # 최근 경기 10건의 matchid 조회
for i in [0,50]:
    match_params = {'matchtype' : 50, 'offset' : i, 'limit' : 5}
    match_record = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/users/{accessid}/matches?',
                                    params=match_params, headers = headers)
    match_id = match_record.json()
    print(match_id)
# Out:
# ['64290ca3956a6e0942ebe282', '6429061e2452f10b1d0f1a89', '6429027fb3b46065bbdc34e9', '6428ffbe4b964a2d1bc9a45d', '6427afc5248a1efe7f0a0f45']
# ['63f9ca067df8002f2bb1ba24', '63f99a30a37c8244ef319f8e', '63f9971b68aa49228b511d92', '63f9941b07b37d5f1d154810', '63f98fcc2362ec187b9328c3']

# %%
len(match_id) # 10건 확인
# Out:
# 5

# %%
match_id
# Out:
# ['63f9ca067df8002f2bb1ba24',
#  '63f99a30a37c8244ef319f8e',
#  '63f9971b68aa49228b511d92',
#  '63f9941b07b37d5f1d154810',
#  '63f98fcc2362ec187b9328c3']

# %%
# 매치 상세 기록 조회 데이터 부르기
matches = pd.DataFrame()
for idx, x in enumerate(match_id):
    matchid = match_id[idx]
    match_info = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{matchid}', headers = headers)
    match_info_data = match_info.json()
    
    matches = pd.concat([matches, pd.DataFrame(match_info_data)], axis = 0)
    
matches # 매치 상세 기록 데이터
# Out:
#                     matchId            matchDate  matchType  \
# 0  63f9ca067df8002f2bb1ba24  2023-02-25T17:53:00         50
# 1  63f9ca067df8002f2bb1ba24  2023-02-25T17:53:00         50
# 0  63f99a30a37c8244ef319f8e  2023-02-25T14:29:01         50
# 1  63f99a30a37c8244ef319f8e  2023-02-25T14:29:01         50
# 0  63f9971b68aa49228b511d92  2023-02-25T14:15:51         50
# 1  63f9971b68aa49228b511d92  2023-02-25T14:15:51         50
# 0  63f9941b07b37d5f1d154810  2023-02-25T14:03:15         50
# 1  63f9941b07b37d5f1d154810  2023-02-25T14:03:15         50
# 0  63f98fcc2362ec187b9328c3  2023-02-25T13:44:29         50
# 1  63f98fcc2362ec187b9328c3  2023-02-25T13:44:29         50
#
#                                            matchInfo
# 0  {'accessId': 'ae549624a3a9b13d544e3ade', 'nick...
# 1  {'accessId': 'ec99bd306d297d1c382a7c03', 'nick...
# 0  {'accessId': '250dd5715a9724965def4ee0', 'nick...
# 1  {'accessId': 'ec99bd306d297d1c382a7c03', 'nick...
# ...

# %%
# 한 경기에 대해 우리팀 상대팀이 index 0, 1로 나눠짐 >> 0과 1로 분리해본다
my_match = matches[matches.index == 0]
your_match = matches[matches.index != 0]

# %%
my_match.index = range(0,len(my_match),1)
your_match.index = range(0,len(your_match),1)
print(my_match.shape , your_match.shape)
your_match
# Out:
# (10, 4) (10, 4)
#                     matchId            matchDate  matchType  \
# 0  63ff3a19a08a327c250654be  2023-03-01T20:52:10         50
# 1  63ff378838720d49c336ef1e  2023-03-01T20:41:34         50
# 2  63ff313bcdb33e3c1199a955  2023-03-01T20:15:10         50
# 3  63ff2de5ebf1ae1e6c260c8b  2023-03-01T19:58:17         50
# 4  63feed534255c226b2a52083  2023-03-01T15:25:30         50
# 5  63fde7374b228976f24831e8  2023-02-28T20:46:34         50
# 6  63fde48d129ada9cafe8a982  2023-02-28T20:34:59         50
# 7  63fde197e7d833f3368521d6  2023-02-28T20:22:17         50
# 8  63fddf0fc9279320df5c928b  2023-02-28T20:11:37         50
# 9  63fddc07e16b45271590ad3f  2023-02-28T19:59:02         50
#
#                                            matchInfo
# 0  {'accessId': 'f5676ace4d0ee7dabf70d957', 'nick...
# 1  {'accessId': 'ec99bd306d297d1c382a7c03', 'nick...
# 2  {'accessId': '09eec193b920d53ed49a15bc', 'nick...
# 3  {'accessId': 'ec99bd306d297d1c382a7c03', 'nick...
# ...

# %%
# matchinfo 에서 유의미한 정보만 빼내기
my_match.matchInfo[0]
# Out:
# {'accessId': 'ec99bd306d297d1c382a7c03',
#  'nickname': '가가나나다라',
#  'matchDetail': {'seasonId': 202302,
#   'matchResult': '패',
#   'matchEndType': 0,
#   'systemPause': 0,
#   'foul': 0,
#   'injury': 1,
#   'redCards': 0,
#   'yellowCards': 0,
#   'dribble': 95,
#   'cornerKick': 3,
#   'possession': 49,
#   'offsideCount': 0,
#   'averageRating': 4.03889,
#   'controller': 'keyboard'},
#  'shoot': {'shootTotal': 8,
#   'effectiveShootTotal': 6,
#   'shootOutScore': 0,
#   'goalTotal': 1,
#   'goalTotalDisplay': 1,
#   'ownGoal': 0,
#   'shootHeading': 2,
#   'goalHeading': 0,
#   'shootFreekick': 0,
#   'goalFreekick': 0,
#   'shootInPenalty': 5,
#   'goalInPenalty': 1,
#   'shootOutPenalty': 3,
#   'goalOutPenalty': 0,
#   'shootPenaltyKick': 0,
#   'goalPenaltyKick': 0},
#  'shootDetail': [{'goalTime': 16777782,
#    'x': 0.8265321850776672,
#    'y': 0.5281033515930176,
#    'type': 2,
#    'result': 2,
#    'spId': 260212814,
#    'spGrade': 6,
#    'spLevel': 3,
# ...

# %% [markdown]
# ### 필요한거
# 1. nickname (my_match, your_match)
# 2. matchDetail > matchResult (my_match)
# 3. shoot > goalTotalDisplay (my_match, your_match)
#
# 요정도만 빼면 될듯

# %%
# nickname
my_match['home_team'] = my_match.matchInfo.apply(lambda x : x['nickname'])
my_match['away_team'] = your_match.matchInfo.apply(lambda x : x['nickname'])

# result
my_match['home_result'] = my_match.matchInfo.apply(lambda x : x['matchDetail']['matchResult'])

# score
my_match['home_score'] = my_match.matchInfo.apply(lambda x : x['shoot']['goalTotalDisplay'])
my_match['away_score'] = your_match.matchInfo.apply(lambda x : x['shoot']['goalTotalDisplay'])
# Out:
# <ipython-input-11-10920c56ef41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_match['home_team'] = my_match.matchInfo.apply(lambda x : x['nickname'])
# <ipython-input-11-10920c56ef41>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_match['away_team'] = your_match.matchInfo.apply(lambda x : x['nickname'])
# <ipython-input-11-10920c56ef41>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
my_match.matchDate = my_match.matchDate.str[0:10]
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# ### 최종 데이터 셋

# %%
match_df = my_match[['matchDate','matchType','home_team','away_team','home_result','home_score','away_score']]
match_df
# Out:
#     matchDate  matchType       home_team away_team home_result  home_score  \
# 0  2023-03-01         50          가가나나다라       짠수박           패           1
# 1  2023-03-01         50           엠피여부장    가가나나다라           패           2
# 2  2023-03-01         50          가가나나다라    력이랑루아랑           패           2
# 3  2023-03-01         50           구월동할렘    가가나나다라           패           0
# 4  2023-03-01         50  lIIllIlIIIlllI    가가나나다라           승           3
# 5  2023-02-28         50     SSongBayern    가가나나다라           무           2
# 6  2023-02-28         50          가가나나다라        땅뜨           무           1
# 7  2023-02-28         50           오산중국집    가가나나다라           무           1
# 8  2023-02-28         50           내일은첼시    가가나나다라           승           2
# 9  2023-02-28         50              쩐북    가가나나다라           패           2
#
#    away_score
# 0           2
# 1           3
# 2           5
# 3           3
# 4           2
# 5           2
# 6           1
# 7           1
# ...

# %% [markdown]
# 이** 사원님의 최근 전적은 좋지 않음을 볼 수 있다...
# 무엇이 그를 4연패로 이끌었는지 알 수 있을까?
# ***
# ## **분석 예시**
# 1. 슛, 패스, 클리어링 같은 다양한 인게임 지표들로 플레이 스타일을 정의할 수 있을까?
# EX) 공격형, 수비형, 밸런스형<br>
#
# 2. 플레이 스타일이 있다면, 상대방과의 플레이스타일 조합이 결과에 유의미한 영향을 끼칠까?
# EX)
# 귀무가설 : 이..사원님은 상대방의 플레이 스타일에 구애받지 않는다.
# 대립가설 : 이..사원님은 공격형 보다 수비형 상대방에게 강하다
#
# ### **카트라이더**
# 카트라이더는 트랙마다 난이도가 표시되어 있다. 하지만 게임할때마다 표시된 난이도랑 실제 난이도의 차이가 심한것 같다. 따라서 데이터를 통해 난이도를 재산정 해보고자 한다.
#
# 주제 : 난이도 재 산정 혹은 세분화를 진행해야되는가?
#
# 1. 난이도에 영향을 주는 지표들 수집 ex) 리타이어 비율, 커브 수, 맵 길이 대비 플레이타임 등
# 2. 찾은 변수들로 유의성 검정
# 3. 실제 난이도와 비교
